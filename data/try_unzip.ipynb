# %%
import gzip
path = 'qm9_cleaned.txt.gz'
with gzip.open(path) as smi:
    lines = smi.readlines()

# %%
lines
# Out:
# [b'C\r\r\n',
#  b'N\r\r\n',
#  b'O\r\r\n',
#  b'C#C\r\r\n',
#  b'C#N\r\r\n',
#  b'C=O\r\r\n',
#  b'CC\r\r\n',
#  b'CO\r\r\n',
#  b'CC#C\r\r\n',
#  b'CC#N\r\r\n',
#  b'CC=O\r\r\n',
#  b'C(=O)N\r\r\n',
#  b'CCC\r\r\n',
#  b'CCO\r\r\n',
#  b'COC\r\r\n',
#  b'C1CC1\r\r\n',
#  b'C1CO1\r\r\n',
#  b'CC(=O)C\r\r\n',
#  b'CC(=O)N\r\r\n',
#  b'C(=O)(N)N\r\r\n',
#  b'CC(C)C\r\r\n',
#  b'CC(C)O\r\r\n',
#  b'C#CC#C\r\r\n',
#  b'C#CC#N\r\r\n',
#  b'C(#N)C#N\r\r\n',
#  b'C#CC=O\r\r\n',
#  b'C(=O)C#N\r\r\n',
#  b'C(=O)C=O\r\r\n',
#  b'CC#CC\r\r\n',
#  b'CCC#C\r\r\n',
#  b'CCC#N\r\r\n',
#  b'C(C#N)N\r\r\n',
#  b'C#CCO\r\r\n',
#  b'C(C#N)O\r\r\n',
#  b'CCC=O\r\r\n',
#  b'CNC=O\r\r\n',
#  b'COC=O\r\r\n',
#  b'C(C=O)O\r\r\n',
#  b'CCCC\r\r\n',
#  b'CCCO\r\r\n',
#  b'CCOC\r\r\n',
#  b'C(CO)O\r\r\n',
#  b'CC1CC1\r\r\n',
#  b'CC1CO1\r\r\n',
#  b'CN1CC1\r\r\n',
#  b'C1CC1O\r\r\n',
#  b'C1CCC1\r\r\n',
#  b'C1COC1\r\r\n',
#  b'CC(=NO)C\r\r\n',
#  b'c1cc[nH]c1\r\r\n',
#  b'c1cnc[nH]1\r\r\n',
# ...
